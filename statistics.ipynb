    'E-GEOD-44712',
    'E-GEOD-45461',
    'E-GEOD-40279',
    'E-GEOD-41169',
    'E-GEOD-32149',
    'E-GEOD-41826',
    'E-GEOD-42700',
    'E-GEOD-32146',
    'E-GEOD-30870',
    'E-GEOD-34639',
    'E-GEOD-63347',
    'E-GEOD-59592'
]

tcga_all = [
    'TGCA_LUSC',
    'TGCA_THCA',
    'TGCA_HNSC',
    'TGCA_KIRC',
    'TGCA_KIRP',
    'TGCA_LUAD',
    'TGCA_PRAD',
    'TGCA_STAD',
    'TGCA_COAD',
    'TGCA_LIHC',
    'TGCA_UCEC',
    'TGCA_BRCA'
]

cancer_data = [
    'GSE32393',
    'GSE37988',
    'GSE26126',
    'GSE63384',
    'GSE59157',
    'E-GEOD-32867',
    'E-GEOD-30759',
    'E-GEOD-31979',
    'E-GEOD-77955',
    'E-GEOD-52068',
    'E-GEOD-49149',
    'E-GEOD-39004'
]

cancer_comparison = [
    'GSE53051',
]

reliability = [
    'GSE55763',
]

rejuvenation = [
    'GSE142439',
    'GSE116754',
    'GSE65214',
    'GSE44430',
    'GSE45727',
    'GSE30653',
    'GSE37066',
    'GSE30456',
]

senescence_analysis = [
    'GSE91069',
    'GSE100249'
]

data_27k = np.concatenate([np.array(geo_data_27k), np.array(array_express_27k)])
data_450k = np.concatenate([np.array(geo_data_450k), np.array(array_express_450k)])
geo_data = np.concatenate([data_27k, data_450k])
tcga_all = np.array(tcga_all)
all_data = np.concatenate([data_27k, data_450k, tcga_all])

# %%
all_data
# Out:
# array(['GSE27317', 'GSE41037', 'GSE38873', 'GSE15745', 'GSE32393',
#        'GSE25892', 'GSE20242', 'GSE22595', 'GSE37988', 'GSE17448',
#        'GSE36642', 'GSE26126', 'GSE34035', 'GSE28746', 'GSE20236',
#        'GSE19711', 'GSE37008', 'GSE36812', 'GSE34257', 'GSE38608',
#        'GSE38291', 'GSE36166', 'GSE63384', 'GSE59274', 'GSE57285',
#        'GSE56606', 'GSE49908', 'GSE49907', 'GSE49905', 'GSE49904',
#        'E-GEOD-43256', 'E-GEOD-64940', 'E-MTAB-2344', 'E-GEOD-62867',
#        'E-GEOD-44763', 'E-GEOD-48988', 'E-GEOD-58119', 'E-GEOD-58045',
#        'E-GEOD-57484', 'E-GEOD-54211', 'E-GEOD-56342', 'E-GEOD-27044',
#        'E-GEOD-36194', 'E-GEOD-21232', 'E-GEOD-32867', 'E-GEOD-30759',
#        'E-GEOD-30758', 'E-GEOD-32396', 'E-GEOD-31979', 'E-MTAB-625',
#        'E-MTAB-487', 'GSE90124', 'GSE115797', 'GSE99624', 'GSE108213',
#        'GSE92767', 'GSE69176', 'GSE40360', 'GSE59157', 'GSE42861',
#        'GSE77241', 'GSE148000', 'E-MTAB-2372', 'E-GEOD-73832',
#        'E-GEOD-71678', 'E-GEOD-71245', 'E-GEOD-83334', 'E-GEOD-75248',
# GSM401967    0.023808    0.172263    0.273176    0.763760    0.055582
# GSM401897    0.027626    0.199632    0.215890    0.763084    0.051756
#
#            cg27655905  cg27657283  cg27662379  cg27662877  cg27665659
# GSM401873    0.066194    0.054622    0.021130    0.027055    0.043460
# GSM402057    0.104593    0.024950    0.022125    0.036666    0.064347
# GSM402037    0.081363    0.028936    0.014836    0.038026    0.054021
# GSM401967    0.087509    0.031111    0.016529    0.034547    0.052878
# GSM401897    0.087914    0.028896    0.020134    0.042407    0.041088
#
# [5 rows x 21372 columns]

# %%
# all test data
count = 0
for dataset in all_data:
    print(dataset)
    new_df = pd.read_pickle('./data_test/' + dataset + '.pkl')
    new_df["source_file"] = dataset

    if count == 0:
        all_test = new_df
        count += 1
    else:
        all_test = pd.concat([all_test, new_df], join='inner')
        gc.collect()
    clear_output()

# only GEO data
count = 0
for dataset in geo_data:
    print(dataset)
    new_df = pd.read_pickle('./data_test/' + dataset + '.pkl')
    new_df["source_file"] = dataset

    if count == 0:
        geo_test = new_df
        count += 1
    else:
        geo_test = pd.concat([geo_test, new_df], join='inner')
        gc.collect()
    clear_output()

# only TGCA data
count = 0
for dataset in tcga_all:
    print(dataset)
    new_df = pd.read_pickle('./data_test/' + dataset + '.pkl')
    new_df["source_file"] = dataset

    if count == 0:
        tgca_test = new_df
        count += 1
    else:
        tgca_test = pd.concat([tgca_test, new_df], join='inner')
        gc.collect()
    clear_output()

# %%
# Check the column names in the dataset
print(all_test.columns)
# Out:
# Index(['dataset', 'tissue_type', 'age', 'gender', 'cg00000292', 'cg00002426',
#        'cg00003994', 'cg00005847', 'cg00007981', 'cg00008493',
#        ...
#        'cg27650434', 'cg27652350', 'cg27653134', 'cg27654142', 'cg27655905',
#        'cg27657283', 'cg27662379', 'cg27662877', 'cg27665659', 'source_file'],
#       dtype='object', length=21373)

# %%
threshold = 40
tissue_counts = all_test['tissue_type'].value_counts()
tissue_counts_grouped = tissue_counts[tissue_counts >= threshold]

other_count = tissue_counts[tissue_counts < threshold].sum()
tissue_counts_grouped['Other'] = other_count

# Plot the pie chart
tissue_counts_grouped.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(8,8), labels=tissue_counts_grouped.index)
plt.title("Tissue Type Distribution All data (Grouped smaller values)")
plt.ylabel("")
plt.show()

tissue_counts_geo = geo_test['tissue_type'].value_counts()
tissue_counts_geo_grouped = tissue_counts_geo[tissue_counts_geo >= threshold]

other_count_geo = tissue_counts_geo[tissue_counts_geo < threshold].sum()
tissue_counts_geo_grouped['Other geo'] = other_count_geo
tissue_counts_geo_grouped.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(8,8), labels=tissue_counts_geo_grouped.index)
plt.title("Tissue Type Distribution GEO Datasets")
plt.ylabel("")
plt.show()

tissue_counts_tgca = tgca_test['tissue_type'].value_counts()
tissue_counts_tgca.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(8,8))
plt.title("Tissue Type Distribution TGCA Datasets")
plt.ylabel("")
plt.show()

# %%
def plot_age_distribution(data, title, bins=50, color='steelblue'):
    plt.hist(data['age'].dropna(), bins=bins, color=color, edgecolor='black')
    plt.xlabel("Age")
    plt.ylabel("Frequency")
    plt.title(title)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

plot_age_distribution(all_test, "Age Distribution Across All Samples", color='mediumslateblue')
plot_age_distribution(geo_test, "Age Distribution Across GEO Samples", color='teal')
plot_age_distribution(tgca_test, "Age Distribution Across TCGA Samples", color='crimson')

# %%
import matplotlib.pyplot as plt

# Function to plot gender distribution with consistent order
def plot_gender_distribution(data, title):
    gender_order = ['M', 'F']  # fixed order
    gender_counts = data['gender'].value_counts().reindex(gender_order)
    colors = ['skyblue', 'salmon']     # blue for male, red for female

    gender_counts.plot(kind='bar', color=colors, edgecolor='black')
    plt.xlabel("Gender")
    plt.ylabel("Frequency")
    plt.title(title)
    plt.xticks(rotation=0)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Plot for all samples
plot_gender_distribution(all_test, "Gender Distribution Across All Samples")

# Plot for GEO samples
plot_gender_distribution(geo_test, "Gender Distribution Across GEO Samples")

# Plot for TCGA samples
plot_gender_distribution(tgca_test, "Gender Distribution Across TCGA Samples")

# %%
all_test.head()
# Out:
#             dataset tissue_type  age gender  cg00000292  cg00002426  \
# GSM675271  GSE27317  blood cord  0.0      F    0.771771    0.857061
# GSM675363  GSE27317  blood cord  0.0      M    0.832678    0.820987
# GSM675235  GSE27317  blood cord  0.0      F    0.899374    0.806204
# GSM675379  GSE27317  blood cord  0.0      M    0.838992    0.885128
# GSM675347  GSE27317  blood cord  0.0      M    0.838790    0.873276
#
#            cg00003994  cg00005847  cg00007981  cg00008493  ...  cg27650434  \
# GSM675271    0.042761    0.181978    0.133760    0.983116  ...    0.127235
# GSM675363    0.103404    0.163862    0.069329    0.975457  ...    0.122359
# GSM675235    0.104971    0.141341    0.079187    0.969639  ...    0.089215
# GSM675379    0.110488    0.186647    0.140228    0.981771  ...    0.050884
# GSM675347    0.121192    0.205484    0.135663    0.982266  ...    0.050949
#
#            cg27652350  cg27653134  cg27654142  cg27655905  cg27657283  \
# GSM675271    0.079499    0.782171    0.045642    0.051613    0.046411
# GSM675363    0.048056    0.856877    0.035531    0.082670    0.046241
# GSM675235    0.111520    0.783498    0.030555    0.072860    0.069916
# GSM675379    0.049137    0.795198    0.037974    0.025419    0.082795
# GSM675347    0.054969    0.815642    0.043966    0.032690    0.066453
#
#            cg27662379  cg27662877  cg27665659  source_file
# GSM675271    0.015018    0.021925    0.031315     GSE27317
# GSM675363    0.021340    0.034114    0.024790     GSE27317
# GSM675235    0.017494    0.048298    0.031741     GSE27317
# GSM675379    0.028651    0.029781    0.029297     GSE27317
# GSM675347    0.023327    0.034468    0.036742     GSE27317
#
# [5 rows x 21373 columns]

# %%
print(all_test.shape)
# Out:
# (5455, 21373)
